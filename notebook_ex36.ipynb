# %%
import plotly.express as px
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
returns = np.random.randn(50)
price = 100 + np.cumsum(returns)

dates = pd.date_range(start='2020-09-01', periods=50, freq='B')
df = pd.DataFrame(zip(dates, price),
                  columns=['Date','Company_A'])
df.head()
# Out:
#         Date   Company_A
# 0 2020-09-01   99.140551
# 1 2020-09-02   99.788803
# 2 2020-09-03   99.749556
# 3 2020-09-04  100.619213
# 4 2020-09-07  100.805664

# %% [markdown]
# 1. Using **Plotly express**, reproduce the plot in the image. As the data is generated randomly I do not expect you to reproduce the same line.
#
# ![alt text][logo_ex6]
#
# [logo_ex6]: ./w1day03_ex6_plot1.png "Time series ex6"
#
# The plot has to contain:
#
# - title
# - x-axis name
# - y-axis name

# %%
fig = px.line(df, x='Date', y='Company_A', title='Company_1 stock price')
fig.show()

# %% [markdown]
# 2. Same question but now using `plotly.graph_objects`. You may need to use `init_notebook_mode` from `plotly.offline`.
#
# - [Resource](https://plotly.com/python/time-series/)

# %%
fig = go.Figure([go.Scatter(x=df['Date'], y=df['Company_A'])])
fig.update_layout(xaxis_title='Date', yaxis_title='Price', title='Company_1 stock price')
fig.show()
